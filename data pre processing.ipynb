div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 1   <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 2   <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 3   <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 4   <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 5   <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 6   <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 7   <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 8   <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 9   <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 10  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 11  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 12  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 13  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 14  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 15  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 16  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 17  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 18  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 19  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 20  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 21  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 22  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 23  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 24  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 25  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 26  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 27  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 28  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 29  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 30  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 31  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 32  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 33  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 34  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 35  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 36  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 37  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 38  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...
# 39  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-u...

# %%
File["price"]=File["price"].str.strip('<div class=""css-146c3p1 r-cqee49 r-1vgyyaa r-ubezar r-1rsjblm r-13hce6t"" dir=""auto"">,</div>').astype(str)

# %%
File
# Out:
#     Unnamed: 0                                               name price
# 0            0  Samyang Flavour Fusion Noodle Combo Carbonara,...  ₹485
# 1            1  Samyang Buldak 3X Spicy Hot Chicken Flavor 140...  ₹275
# 2            2  Samyang Hot Chicken Ramen Buldak Cheese Noodle...  ₹348
# 3            3  Samyang Hot Chicken Ramen Jijang Flavoured Noo...    ₹2
# 4            4  Samyang 3X Spicy Hot Chicken Flavour - 140gm*2...    ₹2
# 5            5  Samyang Flavor Fusion Noodle Combo ||Carbonara...  ₹490
# 6            6  Samyang Flavor Fusion Noodle Combo ||Carbonara...  ₹475
# 7            7  MasterChow Whole Wheat Noodles Kit (Pack of 2)...   ₹27
# 8            8  Samyang 2X Spicy Hot Chicken Flavour Instant K...  ₹332
# 9            9  Samyang Flavor Fusion Noodle Combo||Carbonara|...   ₹47
# 10          10  Samyang Buldak Stir Fried Hot Chicken Flavour ...  ₹332
# 11          11  GrainShakti PREMUIM VEG NOODLES, ATTA NOODLES ...     ₹
# 12          12  Samyang 3XSPICY Hot Chicken Ramen Flavour -140...     ₹
# 13          13  Samyang Hot Chicken Ramen Quattro Cheese Noodl...  ₹360
# 14          14  Samyang 2X Spicy Noodles 140 g & Cheese Noodle...  ₹345
# 15          15  GrainShakti PREMUIM VEG NOODLES - ROLL Hakka N...     ₹
# 16          16  GrainShakti PREMUIM FLAT EGG NOODLES - CHEEZIE...     ₹
# 17          17  fittr Multi-Millet Noodles | No Maida | Not Fr...  ₹250
# 18          18  Samyang Buldak Stir Fried Hot Chicken Flavour ...     ₹
# 19          19  UMAI Udon Traditional Wheat, 300g Instant Nood...    ₹2
# 20          20    UMAI Buckwheat Noodles Hakka Noodles Vegetarian  ₹205
# 21          21  Millet 'n' Minutes MULTI MILLET Hakka Noodles ...  ₹122
# 22          22         TOP RAMEN Curry Instant Noodles Vegetarian    ₹7
# 23          23  Ching's Secret Veg Hakka Noodles, Hakka Noodle...  ₹120
# 24          24  Ottogi Jin Ramen Instant Noodles, Mild, 120g, ...     ₹
# 25          25      Nissin Mazedaar Masala Cup Noodles Vegetarian   ₹48
# 26          26  MasterChow Udon Noodles Pack (Pack of 2) | No ...    ₹2
# 25      Nissin Mazedaar Masala Cup Noodles Vegetarian   ₹48
# 26  MasterChow Udon Noodles Pack (Pack of 2) | No ...    ₹2
# 27  Wai Wai ready to eat Instant Noodles Non-veget...   ₹55
# 28  Wang Ramen Korean Style hot and spicy Ramen In...  ₹550
# 29   Nissin Spiced Chicken Cup Noodles Non-vegetarian   ₹47
# 30  Ching's Secret Manchurian Instant Noodles Vege...    ₹5
# 31  Wai Wai Masala Delight Super Saver Instant Noo...     ₹
# 32  Ching's Secret Hot Garlic Instant Noodles Vege...    ₹5
# 33  Ching's Secret Schezwan Instant Noodles Vegeta...    ₹5
# 34  GrainShakti PREMUIM ATTA NOODLES - ROLL Hakka ...     ₹
# 35  TOP RAMEN Yummy Masala Instant Noodles Vegetarian     ₹
# 36  Samyang Flavor Fusion Noodle Combo ||Carbonara...   ₹50
# 37  Samyang Sam-yang Ramen Extra Spicy Flavour 120...    ₹2
# 38  Samyang Spicy Hot Chicken Flavour Ramen Instan...  ₹140
# 39  Samyang Sam-yang Ramen Extra Spicy Flavour 120...  ₹402

# %% [markdown]
# # catagorical data

# %%
salary_data=pd.DataFrame({"Salary":[10000,20000,30000,40000,50000,60000],"Range":['low','low','mid','mid','high','high']})

# %%
salary_data
# Out:
#    Salary Range
# 0   10000   low
# 1   20000   low
# 2   30000   mid
# 3   40000   mid
# 4   50000  high
# 5   60000  high

# %%
code=salary_data.Range.map({'low':3,'high':1,'mid':2})

# %%
code
# Out:
# 0    3
# 1    3
# 2    2
# 3    2
# 4    1
# 5    1
# Name: Range, dtype: int64

# %%
publish=pd.DataFrame(salary_data['Salary'],columns=['Salary'])

# %%
publish["code"]=code

# %%
publish
# Out:
#    Salary  code
# 0   10000     3
# 1   20000     3
# 2   30000     2
# 3   40000     2
# 4   50000     1
# 5   60000     1

# %% [markdown]
# # Feature scaling

# %%
import numpy as np

# %%
Test_Data=pd.DataFrame({'x':np.random.randint(-1,100,1000),'y':np.random.randint(-50,50,1000),'z':np.random.randint(-200,200,1000)})

# %%
Test_Data
# Out:
#       x   y    z
# 0    95  18   28
# 1    31   3 -200
# 2    94  21  108
# 3    54 -42  118
# 4     2 -38  184
# ..   ..  ..  ...
# 995  57  45  -14
# 996  10  27 -107
# 997  71 -17   50
# 998  46  11  161
# 999  47 -29   38
#
# [1000 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
pl=plt.axes(projection='3d')

# %%
pl.scatter3D(Test_Data.x,Test_Data.y,Test_Data.z)

# %%
plt.figure()

# %%
pl=plt.axes(projection='3d')
pl.scatter3D(Test_Data.x,Test_Data.y,Test_Data.z)
plt.figure()

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\sn115\anaconda\envs\keerthanaak\lib\site-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\sn115\anaconda\envs\keerthanaak\lib\site-packages (from scikit-learn) (1.26.0)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\sn115\anaconda\envs\keerthanaak\lib\site-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\sn115\anaconda\envs\keerthanaak\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sn115\anaconda\envs\keerthanaak\lib\site-packages (from scikit-learn) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import Normalizer
