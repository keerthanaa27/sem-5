# %% [markdown]
# # web scrpping

# %%
#pip install bs4

# %%
from bs4 import BeautifulSoup

# %%
import pandas as pd

# %%
import requests

# %%
url="https://www.shopsy.in/search?q=ramen+noodles&sid=eat,pqj&as=on&as-show=on"

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
Back_code=BeautifulSoup(response.text)

# %%
Back_code
# Out:
# <!DOCTYPE html>
# ...

# %%
Product_name=Back_code.select(".r-zl2h9q")

# %%
Product_name
# Out:
# [<div class="css-146c3p1 r-uia4a0 r-1h7g6bg r-1et8rh5 r-1b43r93 r-1dpkw9 r-zl2h9q r-1s2bzr4" dir="auto">Food Products</div>,
#  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-1b43r93 r-14yzgew r-zl2h9q r-1udh08x">Samyang Flavor Fusion Noodle Combo ||Carbonara||2X||Stir Fried|| 140 gm each Instant Noodles Non-vegetarian</span>,
#  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-1b43r93 r-14yzgew r-zl2h9q r-1udh08x">Samyang 3X Spicy Hot Chicken Flavour - 140gm*2Pack (Imported) Combo Instant Noodles Non-vegetarian</span>,
#  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-1b43r93 r-14yzgew r-zl2h9q r-1udh08x">MasterChow Whole Wheat Noodles Kit (Pack of 2) | No Artificial Color | Made in Small Batches | Fresh From the Kitchen | Get Restaurant Style Taste in Just 10 Minutes | Serves 4-5 Meals Instant Noodles Vegetarian</span>,
# ...

# %%
Price=Back_code.select(".r-1rsjblm.r-13hce6t")

# %%
Price
# Out:
# [<div class="css-146c3p1 r-cqee49 r-1vgyyaa r-ubezar r-1rsjblm r-13hce6t" dir="auto">₹460</div>,
#  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-ubezar r-1rsjblm r-13hce6t" dir="auto">₹284</div>,
#  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-ubezar r-1rsjblm r-13hce6t" dir="auto">₹264</div>,
#  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-ubezar r-1rsjblm r-13hce6t" dir="auto">₹317</div>,
#  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-ubezar r-1rsjblm r-13hce6t" dir="auto">₹464</div>,
#  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-ubezar r-1rsjblm r-13hce6t" dir="auto">₹274</div>,
#  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-ubezar r-1rsjblm r-13hce6t" dir="auto">₹224</div>,
#  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-ubezar r-1rsjblm r-13hce6t" dir="auto">₹334</div>,
#  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-ubezar r-1rsjblm r-13hce6t" dir="auto">₹333</div>,
#  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-ubezar r-1rsjblm r-13hce6t" dir="auto">₹464</div>,
# ...

# %%
Mobile_data=pd.DataFrame(Product_name,columns=["Name"])

# %%
Mobile_data
# Out:
#                                                  Name
# 0                                       Food Products
# 1   Samyang Flavor Fusion Noodle Combo ||Carbonara...
# 2   Samyang 3X Spicy Hot Chicken Flavour - 140gm*2...
# 3   MasterChow Whole Wheat Noodles Kit (Pack of 2)...
# 4   Samyang 2X Spicy Hot Chicken Flavour Instant K...
# 5   Samyang Flavor Fusion Noodle Combo||Carbonara|...
# 6   Samyang Buldak 3X Spicy Hot Chicken Flavor 140...
# 7   Samyang Hot Chicken Ramen Jijang Flavoured Noo...
# 8   Samyang 3XSPICY Hot Chicken Ramen Flavour -140...
# 9   Samyang Hot Chicken Ramen Buldak Cheese Noodle...
# 10  Samyang Flavor Fusion Noodle Combo ||Carbonara...
# 11  Samyang Buldak Stir Fried Hot Chicken Flavour ...
# 12  Millet 'n' Minutes MULTI MILLET Hakka Noodles ...
# 13  Samyang 2X Spicy Noodles 140 g & Cheese Noodle...
# 14  Samyang Flavour Fusion Noodle Combo Carbonara,...
# 15  GrainShakti PREMUIM VEG NOODLES - ROLL Hakka N...
# ...

# %%
Mobile_data.to_csv("MOBILE.csv")

# %%
file=pd.read_csv("MOBILE.csv")

# %%
file
# Out:
#     Unnamed: 0                                               Name
# 0            0                                      Food Products
# 1            1  Samyang Flavor Fusion Noodle Combo ||Carbonara...
# 2            2  Samyang 3X Spicy Hot Chicken Flavour - 140gm*2...
# 3            3  MasterChow Whole Wheat Noodles Kit (Pack of 2)...
# 4            4  Samyang 2X Spicy Hot Chicken Flavour Instant K...
# 5            5  Samyang Flavor Fusion Noodle Combo||Carbonara|...
# 6            6  Samyang Buldak 3X Spicy Hot Chicken Flavor 140...
# 7            7  Samyang Hot Chicken Ramen Jijang Flavoured Noo...
# 8            8  Samyang 3XSPICY Hot Chicken Ramen Flavour -140...
# 9            9  Samyang Hot Chicken Ramen Buldak Cheese Noodle...
# 10          10  Samyang Flavor Fusion Noodle Combo ||Carbonara...
# 11          11  Samyang Buldak Stir Fried Hot Chicken Flavour ...
# 12          12  Millet 'n' Minutes MULTI MILLET Hakka Noodles ...
# ...

# %%
data_frame_price=pd.DataFrame(Product_name,columns=["name"])

# %%
data_frame_price["price"]=Product_name

# %%
data_frame_price
# Out:
#                                                  name  \
# 0                                       Food Products
# 1   Samyang Flavor Fusion Noodle Combo ||Carbonara...
# 2   Samyang 3X Spicy Hot Chicken Flavour - 140gm*2...
# 3   MasterChow Whole Wheat Noodles Kit (Pack of 2)...
# 4   Samyang 2X Spicy Hot Chicken Flavour Instant K...
# 5   Samyang Flavor Fusion Noodle Combo||Carbonara|...
# 6   Samyang Buldak 3X Spicy Hot Chicken Flavor 140...
# 7   Samyang Hot Chicken Ramen Jijang Flavoured Noo...
# 8   Samyang 3XSPICY Hot Chicken Ramen Flavour -140...
# 9   Samyang Hot Chicken Ramen Buldak Cheese Noodle...
# 10  Samyang Flavor Fusion Noodle Combo ||Carbonara...
# 11  Samyang Buldak Stir Fried Hot Chicken Flavour ...
# 12  Millet 'n' Minutes MULTI MILLET Hakka Noodles ...
# 13  Samyang 2X Spicy Noodles 140 g & Cheese Noodle...
# 14  Samyang Flavour Fusion Noodle Combo Carbonara,...
# 15  GrainShakti PREMUIM VEG NOODLES - ROLL Hakka N...
# ...

# %%
data_frame_price.to_csv("MOBILE.csv")
